# %% [markdown]
# **Adrian Arroyo Perez** / AI Engineer
#
# Template notebook for Data Science and MLOps methodology for ML projects showing the whole process from analysing the data to training the models, with a set of examples and useful documentation.
#
# According to Andrew NG., this is the process we should follow for any ML project:
#
# ![mlops.png](data:image/png;base64,...)

# %% [markdown]
# # 0. General information.

# %% [markdown]
# **AUTHOR** / *Role*

# %% [markdown]
# **About the problem and the data set:**
#
# Description about the data and how it can be used to solve the problem.

# %% [markdown]
# # 1. Instalations, auxiliary functions and general `imports`.

# %%
# %pip install

# %%
import

# %% [markdown]
# # 2. Exploratory Data Analysis.

# %% [markdown]
# Usefull documentation and examples:
#
# *   [Kaggle Notebook with generic EDA process](https://www.kaggle.com/ekami66/detailed-exploratory-data-analysis-with-python)
# *   [Adobe notebook with generic EDA process](https://experienceleague.adobe.com/docs/experience-platform/data-science-workspace/jupyterlab/eda-notebook.html?lang=en)
#
#
# Some data analysis frameworks:
#
# *   [Tensorflow Data Validation](https://www.tensorflow.org/tfx/data_validation/get_started)
# *   [Data Science Tools repository](https://github.com/khuyentran1401/Data-science)
#
#
# Some notebook tools for EDA:
#
# * [Sweetviz](https://pypi.org/project/sweetviz/)

# %% [markdown]
# ## 2.1 Asking Analytical Questions and Visualizations

# %% [markdown]
# This section aims at helping the developer to look at the problem from a wider point of view, so that he/she takes the best decisions on what operations will be performed on the data to find the problem's solution as accurate and informative as possible. Basically, this can be done through a set of questions that are asked and answered from different points of view.
#
# Some useful articles about this:
#
# *   [Essential questions to ask before starting a data science problem](https://towardsdatascience.com/essential-questions-to-ask-before-starting-a-data-science-project-cd633dcd9d55)
# *   [Data analysis questions](https://www.datapine.com/blog/data-analysis-questions/)
# *   [Checklist before starting a ML project](https://skimai.com/checklist-starting-a-machine-learning-project/)
#
#
# Some key questions:
#
# 1.   What is the core problem and focus of the project?
# 2.   How can you ensure data quality?
# 3.   What metrics will be used to gauge success of the project, and at what threshold(s)?
# 4.   How will my analysis be used?

# %% [markdown]
# ## 2.2. Loading the dataset and checking its content.

# %% [markdown]
# ## 2.3 Data Preprocessing

# %% [markdown]
# According to the following useful articles, the data preprocessing phase can be divided into several steps.
#
# *   [Data Preprocessing](https://monkeylearn.com/blog/data-preprocessing/)
# *   [Data preprocessing concepts](https://towardsdatascience.com/data-preprocessing-concepts-fa946d11c825)
# *   [Data preprocessing guide](https://www.v7labs.com/blog/data-preprocessing-guide)
# *   [Data preprocessing in data mining](https://www.geeksforgeeks.org/data-preprocessing-in-data-mining/)

# %% [markdown]
# ### 2.3.1 Data Cleaning: dealing with missing values and outliers.

# %% [markdown]
# 1.   **Dealing with missing values**:
#     *   [Techniques for dealing with missing values](https://www.analyticsvidhya.com/blog/2021/10/guide-to-deal-with-missing-values/)
#     *   [Scikit-learn guide](https://scikit-learn.org/stable/modules/impute.html#)
# 2.   **Finding outliers**:
#     *   [Techniques for finding outliers](https://www.analyticsvidhya.com/blog/2021/05/feature-engineering-how-to-detect-and-remove-outliers-with-python-code/)
#     *   [Scikit-learn guide](https://scikit-learn.org/stable/modules/outlier_detection.html)

# %% [markdown]
# ### 2.3.2 Data Transformation
#
# There can be applied different forms of transformations over the data, with the objective to make it as informative as possible not only for the ML processes but also to enable some smart visualizations of the data.
#
# 1.   **Normalization**: scale the data values in a specified range (ex.: -1.0 to 1.0 or 0.0 to 1.0)
# 2.   **Attribute Selection**: new attributes are constructed from the given set of attributes, like computing mean of two attributes, transforming some attributes according to some predefined knowledge, etc.
# 3.   **Aggregation**: storing and presenting data in a summary format. For example sales data can be aggregated and transformed to show as per month and year format.
# 4.   **Concept Hierarchy Generation or Generalization**: attributes are converted from lower level to higher level in hierarchy. For example the attribute “city” can be converted to “country”.

# %% [markdown]
# ### 2.3.3 Data Reduction
#
# This is a similar process as before, but here we aim at removing redundant information or transforming data into a simpler form.
#
# 1.   **Dimensionality reduction**: To reduce the size of data by encoding mechanisms, which can be lossy or lossless. If after the reconstruction from compressed data, the original data can be retrieved, such reduction is called lossless, otherwise it is called lossy. One example of a lossy dimensionality reduction is PCA (Principal Component Analysis).
# 2.   **Discretization**: it is used to divide the attributes of continuous nature into data with intervals. After discretizing a variable, groups corresponding to the target can be interpreted. For example, attribute age can be discretized into bins like below 18, 18-44, 44-60 and above 60.
# 3.   **Data Cube Aggregation**:  the data is expressed in a summary form, similar to the aggregation transformation in the previous step but here we are interested in a more generic point of view.
# 4.   **Numerosity reduction**: The data can be represented as a model or equation like a regression model. This would save the burden of storing huge datasets but instead storing only a model.

# %% [markdown]
# # 3. Training a Machine Learning Model

# %% [markdown]
# ## 3.1 Data preparation for ML
#
# There is still another data transformation phase which is very specific to ML as it is only done when the data is going to be processed by a model.
#
# 1. **Feature Encoding**: performing transformations on the data such that it can be easily accepted as input for machine learning algorithms while still retaining its original meaning.
# 2. **Train / Validation / Test Split**
#     * _Training data_: This is the part on which your machine learning algorithms are actually trained to build a model. The model tries to learn the dataset and its various characteristics and intricacies, which also raises the issue of Overfitting v/s Underfitting.
#     * _Validation data_: This is the part of the dataset which is used to validate our various model fits. In simpler words, we use validation data to choose and improve our model hyperparameters. The model does not learn the validation set but uses it to get to a better state of hyperparameters.
#     * _Test data_: This part of the dataset is used to test our model hypothesis. It is left untouched and unseen until the model and hyperparameters are decided, and only after that the model is applied on the test data to get an accurate measure of how it would perform when deployed on real-world data.

# %% [markdown]
# ## 3.2 Training a baseline model to check if the problem can be solved with the data

# %% [markdown]
# Some common ML frameworks to train models:
#
# *   [Tensorflow](https://tensorflow.org/)
# *   [Pytorch](https://pytorch.org/)
# *   [Scikit-Learn](https://scikit-learn.org/)
# *   [XGBoost](https://xgboost.readthedocs.io/)
#
#
# **If the model is not able to learn, this may imply to go back to any of previous steps and check that we have enough data and that its quality is as good as possible.**

# %% [markdown]
# ## 3.3 Improving the model

# %% [markdown]
# Examples of techniques for improving the model once it learns with a minimum acceptance criteria we have previously met:
#
# *   [Feature selection](https://www.analyticsvidhya.com/blog/2020/10/feature-selection-techniques-in-machine-learning/)
#     *    [Scikit-learn feature selection](https://scikit-learn.org/stable/modules/feature_selection.html)
# *   [Hyperparameter tuning](https://en.wikipedia.org/wiki/Hyperparameter_optimization)
#     *    [Scikit-Learn tuners](https://scikit-learn.org/stable/modules/grid_search.html#grid-search)
# *   [Ensemble methods](https://machinelearningmastery.com/tour-of-ensemble-learning-algorithms/)
#     *    [Scikit-Learn ensemble](https://scikit-learn.org/stable/modules/ensemble.html#ensemble)
# *   [Synthetic data generation](https://research.aimultiple.com/synthetic-data-generation/)
#
# **If we are unable to improve the model, it may imply to go back to previous steps, starting in chaning our model architecture or framework for another.**

# %% [markdown]
# ## 3.3 Testing the model against new data and validating its behaviour

# %% [markdown]
# Example tools for testing and validating models:
#
# *   [Tensorflow model analysis](https://github.com/tensorflow/model-analysis)
# *   [SHAP: Model explainability](https://shap.readthedocs.io/en/latest/index.html)
#
#
# **Again, if the validation phase is unsuccessfull, we will need to go back and iterate over the previous steps again.**

# %% [markdown]
# # 4. Process monitoring and encapsulation as a pipeline

# %% [markdown]
# Usefull tools and frameworks:
#
# Pipeline creation:
#
# *   [Kubeflow Pipelines](https://github.com/kubeflow/pipelines)
# *   [Tensorflow extended](https://www.tensorflow.org/tfx)
# *   [SKLearn pipelines](https://scikit-learn.org/stable/modules/compose.html#combining-estimators)
#
# Metadata monitoring:
#
# *   [Tensorflow ml metadata](https://www.tensorflow.org/tfx/guide/mlmd#data_model)
